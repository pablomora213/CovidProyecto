# %%
import pandas as pd
import numpy as np
import folium
from googletrans import Translator
import mysql.connector as conn

# %%
poblacion= pd.read_csv("poblacion.csv")
alcohol= pd.read_csv("HappinessAlcoholConsumption.csv")
deaths= pd.read_csv("all_weekly_excess_deaths.csv")
medallas= pd.read_csv("medallas.csv")

# %%
poblacion
# Out:
#                                     PAÍS      POBLACIÓN
# 0                                  China  1,439,323,774
# 1                                  India  1,380,004,385
# 2                          United States    331,002,647
# 3                              Indonesia    273,523,621
# 4                               Pakistan    220,892,331
# ..                                   ...            ...
# 195                                Aruba        106,766
# 196                                Tonga        105,697
# 197  Virgin Islands of the United States        104,423
# 198                           Seychelles         98,340
# 199                      Old and bearded         97,928
#
# [200 rows x 2 columns]

# %%
listpa=[]

# %%
listpa=listpa+(list(medallas['pais'].unique()))

# %%
listpa=listpa+(list(alcohol['Country'].unique()))

# %%
listpa=listpa+(list(deaths['country'].unique()))

# %%
listpa
# Out:
# ['United States',
#  'Russia',
#  'United Kingdom',
#  'China',
#  'Germany',
#  'France',
#  'Italy',
#  'Hungary',
#  'Japan',
#  'Australia',
#  'Sweden',
#  'Finland',
#  'South Korea',
#  'Netherlands',
#  'Romania',
#  'Cuba',
#  'Poland',
#  'Canada',
#  'Norway',
#  'Bulgaria',
#  'New Zealand',
#  'Switzerland',
#  'Czechoslovakia',
#  'Denmark',
#  'Spain',
#  'Unified Equipment',
#  'Belgium',
#  'Turkey',
#  'Brazil',
#  'Greece',
#  'Kenya',
#  'Ukraine',
#  'Yugoslavia',
#  'South Africa',
#  'Jamaica',
#  'Iran',
#  'Ethiopia',
#  'Argentina',
#  'Austria',
#  'North Korea',
#  'Kazakhstan',
#  'Croatia',
#  'Belarus',
#  'Mexico',
#  'Ireland',
#  'Slovakia',
#  'Georgia',
#  'Estonia',
#  'India',
#  'Thailand',
#  'Uzbekistan',
#  'Indonesia',
#  'Egypt',
#  'Slovenia',
#  'Bahamas',
#  'Azerbaijan',
#  'Morocco',
#  'Lithuania',
#  'Serbia',
#  'Colombia',
#  'Portugal',
#  'Algeria',
#  'Latvia',
#  'Venezuela',
#  'Uganda',
#  'Tunisia',
#  'Niger',
# ...

# %%
set(listpa)
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Barbados',
#  'Baréin',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bohemia',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Britain',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Czechoslovakia',
#  'Dem. Rep. Congo',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Federation of Western Indies',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenoble',
#  'Guatemala',
#  'Guyana',
#  'Haiti',
#  'Honduras',
# ...

# %%
listpais=pd.DataFrame(listpa)

# %%
listpais
# Out:
#                   0
# 0     United States
# 1            Russia
# 2    United Kingdom
# 3             China
# 4           Germany
# ..              ...
# 303           Spain
# 304          Sweden
# 305     Switzerland
# 306         Tunisia
# 307   United States
#
# [308 rows x 1 columns]

# %%
listpais.to_csv("listpais.csv", index=False)
